# %% [markdown]
# ## 数据容器-str(字符串)
# 在python中字符串也是一个数据容器，它主要存放的是字符，一个字符串可以存放任意数量的字符

# %% [markdown]
# ### 字符串的创建
# 在之前我们已经学过了字符串的创建，可以使用``''``,``""``,```''''''```,`""""""`,str函数这五种方式创建，同样的我们之前在学习其他数据类型转换成字符串的时候就学过str()方法，所以这里就不细讲

# %%
# 字符串的创建
str_1 = '123'
str_2 = "abcd"
str_3 = '''xiaoming'''
str_4 = """qwe"""


str_5 = str(123)   # 可以填写任意数据类型的元素
print(str_5)
# Out:
# 123

# %%
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
print(len(str([1,2,3,4])))
# Out:
# 12

# %%
# 使用str函数将其他类型转换为字符串

# %% [markdown]
# 注意：所有的数据类型都可以转换为字符串类型 但是要注意数据类型的格式化问题

# %% [markdown]
# 有序

# %%
#        -5-4-3-2-1
str_1 = 'abcde'
#        01234

# %%
# 通过下标访问对应下标的元素
print(str_1[2])
# Out:
# c

# %%
print(str_1[-2])
# Out:
# d

# %% [markdown]
# 存储重复的元素

# %%
str_1 = 'hello world'
print(str_1)
# Out:
# hello world

# %% [markdown]
# 只能存储字符串的元素

# %%
str_1 = '123456'

# %% [markdown]
# 这里面的`123456`,都是一个个的字符串，而不是数字类型的元素

# %% [markdown]
# 不可以被修改

# %%
# 1. 通过下标访问对应的元素str[]
str_1 = 'abcde'
print(str_1[2])
# Out:
# c

# %%
# 2.获取某个字符出现的次数 str.count()
str_1 = 'hello world'
print(str_1.count('l'))
# Out:
# 3

# %%
# 3.获取某个元素出现第一次的下标str.index()
str_1 = 'hello world'
print(str_1.index('l'))
# Out:
# 2

# %%
# 4.获取字符串中字符的个数len()
str_1 = 'hello world'
len(str_1)
# Out:
# 11

# %% [markdown]
# ### 字符串的操作
# 字符串跟之前学过的列表和元组一样，都有元素对应的下标，可以通过元素对应的下标去找到对应的元素，这里的字符串存储的主要是一个个字符，可以理解成将一个字符串拆分成了多个字符，以一个容器的形式进行存储。我们可以简单的给出字符串的特点：1.有序；2.存储重复的元素；3.不可被修改
#
# 操作:
#
# 1. 通过下标访问对应的字符
# 2. `str.count(字符串)`:返回该参数字符串出现的次数
# 3. `str.index()`:通过给定字符返回第一个匹配的下标
# 4. `len(字符串)`：返回字符串的字符个数
# 5. `str.replace(字符串1，字符串2)`:将字符串内的全部字符串1中的字符串，全部替换为字符串2，该操作是非破坏性，会得到一个新的字符串
# 6. `str.split(字符串)`:按照指定的分隔符将字符串划分为多个字符串，并存入一个新的列表对象中，进行返回，非破坏性
# 7. `str.strip(字符串)`:移除首尾指定的字符串，会以一个新的字符串进行返回；注意：如果没有参数，表示移除空格字符,
# 8. `'拼接的字符'.join(str)`：将可迭代对象（数据容器）中的多个字符串连接起来，用指定的分隔符拼接成一个新的字符串。注意数据容器中必须都是字符串
# 9. `str.lower()`:将str中的所有大写转换为小写字母
# 10. `str.upper()`：将str中的所有小写转换为大写字母

# %%
# 实例代码  str特有的一些方法

# 5.字符串中的指定部分替换为其他字符串    str.replace()    非破坏性方法
str_1 = 'hello world'
new_str = str_1.replace('world', 'python')  # 产生一个新的字符串
print(new_str)
print(str_1)
# Out:
# hello python
# hello world

# %%
# 6.按照指定的分隔符进行分隔，默认的分隔符为空格    str.split()   非破坏性方法
str_1 = '100,100,98,98,76'
new_str = str_1.split(',')
print(new_str)
# Out:
# ['100', '100', '98', '98', '76']

# %%
str_1 = 'hello world'
new_str = str_1.split()
print(new_str)
# Out:
# ['hello', 'world']

# %%
str_1 = ' hello world hello world hello world'
new_str = str_1.split()
print(new_str)
# Out:
# ['hello', 'world', 'hello', 'world', 'hello', 'world']

# %% [markdown]
# 注意：默认的分隔符为空格

# %%
str_1 = ',hello,world,hello,world,hello,world'
new_str = str_1.split(',')  # 用`,`分割
print(new_str)
# Out:
# ['', 'hello', 'world', 'hello', 'world', 'hello', 'world']

# %% [markdown]
# 练习：编写程序，让用户输入一串数字（数字之间用空格分隔），将输入的数字存入列表，计算并打印这些数字的总和以及平均值。

# %%
# number = input("请输入一串数字（数字之间用空格分隔）：")
# print(number)
number = '100,100,45,89,90'
number_list = number.split(',')
print(number_list)
result = 0  # 总和
for i in number_list:
    result = result + int(i)
print(result)
print(result/ len(number_list))
# Out:
# ['100', '100', '45', '89', '90']
# 424
# 84.8

# %%
# 7.移除首尾指定的字符串，会以一个新的字符串进行返回 默认参数为空格   str.strip()  非破坏性方法
str_1 = 'qello world hello world hello world hello'
new_str_1 = str_1.strip("hello")
print(new_str_1)
# Out:
# qello world hello world hello world

# %%
str_1 = 'oeelo world hello world hello world heole'
new_str_1 = str_1.strip("hello")
print(new_str_1)
# Out:
#  world hello world hello world

# %%
str_1 = '    oeelo world hello world hello world heole    '
new_str_1 = str_1.strip()
print(new_str_1)
# Out:
# oeelo world hello world hello world heole

# %% [markdown]
# 100,85,85,95,74,52

# %%
# 8.join 连接字符串
# join方法
new_str = ', '.join(['100','20000','300','4000'])  # 参数 填写一个数据容器  这个数据容器中的所有元素都必须是字符串
print(new_str)
# Out:
# 100, 20000, 300, 4000

# %%
# 9.下降  大写转换为小写   str.lower()  
str_1 = 'hello WORLD'
new_str = str_1.lower()
print(new_str)
# Out:
# hello world

# %%
# 10.上升 小写转换为大写  str.upper()
str_1 = 'hello WORLD'
new_str = str_1.upper()
print(new_str)
# Out:
# HELLO WORLD

# %% [markdown]
# ### 字符串的遍历
# 字符串跟列表和元组一样，都可以使用while和for循环通过下标进行遍历<br>
# while循环遍历<br>
# for循环遍历<br>

# %%
# while循环遍历
str_1 = 'hello world'
i = 0
n = len(str_1)
while i <= n -1:
    print(str_1[i])
    i = i + 1
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
# for循环遍历
str_1 = 'hello world'
for i in str_1:
    print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# ### 字符串的扩展
# 1. `f'{变量} {变量} {字面量}'`，我们可以使用这种方式去实现拼接字符串的效果。
# 2. `'%xx  %xx '%(变量1,变量2)`，通过使用这种方式我们可以将其格式化输出
#
#        %xx表示为：
#         %x.y[d f s]
#         x:表示占多少位置（字符）
#         y:表示保留小数点后几位
#         格式化输出
#         %d  格式化输出整数
#         %f  格式化输出浮点数
#         %s  格式化输出字符串
#        例如 2.1%f表示占2个字符，保留1位小数，输出格式为浮点数
#
# 3.`'{} {} {}'.format(参数1,参数2,参数3)`：该方式是上述两个方式的结合
#
#         默认情况从左往右占位符{}与参数一一对应。

# %%
# 之前的使用
'我叫小明，我今年18岁，我兜里只有100块钱'

name = '小明'
age = 18
money = 100
infor = "我叫" + name + ',我今年' + str(age) + '岁，我兜里只有' + str(money) + '块钱'
print(infor)
# Out:
# 我叫小明,我今年18岁，我兜里只有100块钱

# %% [markdown]
# 我叫小明，我今年18岁，我兜里只有100块钱

# %%
# 方式1
name = '小明'
age = 18
money = 100
infor = f'我叫{name}，我今年{age}岁，我兜里只有{money}块钱'
print(infor)
# Out:
# 我叫小明，我今年18岁，我兜里只有100块钱

# %%
# 方式2
infor = '我叫%1s，我今年%d岁，我兜里只有%.2f块钱'%(name, age, money)
print(infor)
# Out:
# 我叫小明，我今年18岁，我兜里只有100.00块钱

# %% [markdown]
# 注意：\
# 1.一般情况下，我们是对应的格式化输出，整数使用整数的格式化输出，浮点数使用浮点数的格式化输出，\
# 但是如果你想用其他的格式化输出，满足转换的情况即可（例如：整数使用浮点数输出，浮点数使用整数输出等等）\
# 2.x不填写的默认值为刚好存下该变量的字符大小，如果填写的小于该变量字符的大小，则会扩到刚好存下\
# 3.y不填写的默认值为6。

# %% [markdown]
# 我叫小明，我今年18岁，我兜里只有100.00块钱

# %%
# 方式3
# 格式如下
name = '小明'
age = 18
money = 100
# {} 表示 占位符
# 1. 正常情况下，第一个{}匹配第一个变量，依次类推，匹配多个变量
infor = '我叫{}，我今年{}岁，我兜里只有{}块钱'.format(name, age, money)
print(infor)
# Out:
# 我叫小明，我今年18岁，我兜里只有100块钱

# %%
# 2.可以在{}中填写信息来指定匹配的变量是哪一个，在format()方法中，第一个变量表示0
infor = '我叫{0}，我今年{0}岁，我兜里只有{0}块钱'.format(age, money, name)
print(infor)
# Out:
# 我叫18，我今年18岁，我兜里只有18块钱

# %%
# 3.{}中该可以指定要匹配变量的格式，例如你想让money匹配的结果是一个浮点数
infor = '我叫{:}，我今年{:}岁，我兜里只有{:.2f}块钱'.format(name, age, money)
print(infor)
# Out:
# 我叫小明，我今年18岁，我兜里只有100.00块钱

# %% [markdown]
# **format**中的格式表示
#
# `^`,` <`, `>` 分别是居中、左对齐、右对齐，后面带宽度， `:`号后面带填充的字符，只能是一个字符，不指定则默认是用空格填充。
#
# `+` 表示在正数前显示 `+`，负数前显示 `-`；  （空格）表示在正数前加空格
#
# `b`、`d`、`o`、`x` 分别是二进制、十进制、八进制、十六进制。

# %%
# 尝试一下即可,不需要强行记

# %% [markdown]
# ### 字符串小结
# 1.只可以存储字符串<br>
# 2.长度任意<br>
# 3.字符串中的字符有对应的下标<br>
# 4.允许重复字符串的存在<br>
# 5.**不可以修改** 只能重新赋值，重新赋值不是修改，而是新的字面量<br>
# 6.可以使用for循环进行遍历字符元素<br>
#
# 与列表的区别：1.不可修改；2.只能存储字符串，不能存储其他数据类型<br>
# 与元组的区别：1.只能存储字符串，不能存储其他数据类型<br>

# %% [markdown]
# ### 练习

# %%
# 1.用户输入一句英文句子，请将句子中的单词 "python" 替换为 "C" 并输出结果。

# %%
# 2.给定学生信息字符串列表：["20230101-张三", "20230102-李四", "20230103-王五"]，请将其拆分为学号和姓名两个列表，分别输出。
list_1 = ["20230101-张三", "20230102-李四", "20230103-王五"]
id_list = []
name_list = []
for i in list_1:
    infor_list = i.split('-')
    # ['20230101', '张三']
    id_list.append(infor_list[0])
    name_list.append(infor_list[1])

print(id_list)
print(name_list)
# Out:
# ['20230101', '20230102', '20230103']
# ['张三', '李四', '王五']

# %%
# 3.将字符串 "apple,banana,grape,orange" 按逗号分隔成一个列表，并输出每一个水果名称。

# %%
# 4.给定字符串 " Hello, Python! ", 去除前后多余的空格后输出。

# %%
# 5.用户输入一句英文句子，程序输出全大写和全小写版本

# %%
# 6.将列表 ['Hello', 'Python', 'World'] 中的单词用空格连接成一个完整的句子并输出。
