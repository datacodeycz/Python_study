# %% [markdown]
# # 面向对象（OOP）
# ## 面向对象的基本概述
# python是一种面向对象的编程语言，而python中几乎所有东西都是对象，拥有属性和方法。
#
# 问题：
#
# 1. 什么是面向对象编程
#    - 计算机程序是干什么的
#       - 程序就是对象现实世界的抽象
#    - 对象是干什么的
#       - 一个事物抽象到程序中后就变成了对象
#       - 在程序的世界中，一切皆对象
#    - 面向对象编程是什么
#         - 面向对象的编程就是指，程序中的所有操作都是通过对象来完成的
#         - 做任何事情之前都需要先找到它的对象，然后通过对象来完成各种操作
#
# 2. 为什么要有面向对象
#
#
# 3. 怎么来使用面向对象编程

# %% [markdown]
# ## 对象
# 一个事物抽象到程序就变成了对象，对象中包含了特征（属性）和行为（方法）
#
# 例如：一个大二的学生
#
# 有哪些特征：学号、姓名、班级、成绩等
#
# 有哪些行为：上课、吃饭、睡觉等
#
#
# 我们是无法将这个大二的学生的所有特征和行为都写出来的，但是我们可以写常见的和我们要使用到的，这就将一个实体抽象成了一个程序中的一个对象

# %%
name = "xiaoming"
age = 20
sex = 'nan'

name = 'xiaohong'

# %%
def eat():
    print("去食堂吃饭")

xiaoming = {
    'name':'xiaoming',
    'age':20,
    'sex':'nan',
    'eat':eat
}
# xiaoming['name']
xiaoming['eat']()
# Out:
# 去食堂吃饭

# %%
def eat():
    print("去食堂吃饭")

xiaoming = {
    'name':'xiaohong',
    'age':19,
    'sex':'nv',
    'eat':eat
}

# xiaoming['name']
xiaoming['eat']()
# Out:
# hello world

# %%
def eat():
    print("去食堂吃饭")

xiaoming = {
    'name':'xiaohong',
    'age':19,
    'sex':'nv',
    'eat':eat
}


# xiaoming['name']
xiaoming['eat']()
# Out:
# {'name': 'xiaohong', 'age': '20', 'sex': 'nv'}

# %% [markdown]
# 引入对象

# %% [markdown]
# 上述这些数据都是属于小明的，但怎么确定是小明的啦
#
# 我们可不可以借助对象来表示这些都是小明这个对象的特征

# %% [markdown]
# 创建对象
#
# 在python中创建对象之前，需要有一个创建该对象的模板（蓝图） ----> 类

# %% [markdown]
# 类：创建对象的模板。
#
# 上述的数据虽然都属于小明的，但是每一个大二的学生都有那些特征，只是特征对应的数据不一样。
#
# 所以我们可以创建一个 `创建对象的模板--->类`，然后再通过这个类来创建对象，给这个对象填写属于自己的属性（特征）

# %% [markdown]
# 创建类的格式为
# ```
# class 类名:
#     属性a
#
#     方法
# ```

# %%
# 创建Student类
# 类名首字母大写
class Student:
    # 类作为模板要写的内容
    id_ = None
    name = None
    age = None
    sex = None
    class_ = None

    def __init__(self,id_,name,age,sex,class_):
        self.id_ = id_
        self.name = name
        self.age = age
        self.sex = sex
        self.class_ = class_

# %%
# 通过类创建对象
stu_1 = Student('20240101', 'xiaoming', '20', 'nan', '3')  # 通过类创建student对象
print(stu_1.name)
print(stu_1.id_)
print(type(stu_1))
# Out:
# xiaoming
# 20240101
# <class '__main__.Student'>

# %%
# 给xiaoming这个对象的属性增加属性值
# 1.对象.属性 = 属性值
stu_1.id_ = '20240101'
stu_1.name = 'xiaoming'
stu_1.age = '20'
stu_1.sex = 'nan'
stu_1.class_ = '3'

# %%
# 2.访问对象的属性： 对象.属性
print(stu_1.name)
print(stu_1.id_)
# Out:
# xiaoming
# 20240101
