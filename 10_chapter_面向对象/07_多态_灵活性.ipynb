# %% [markdown]
# ## 多态
#
# 多态是：指多种状态，即完成某个行为时，使用不同的对象会得到不同的状态

# %%
class Animal:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

    def __str__(self):
        return f'name:{self.name}, age:{self.age}, sex:{self.sex}'

    def say(self):
        return "动物叫"

# %%
class Cat(Animal):
    def __init__(self, name, age, sex, color):
        Animal.__init__(self, name, age, sex)
        self.color = color
    def __str__(self):
        return f'name:{self.name}, age:{self.age}, sex:{self.sex}, color:{self.color}'
    def say(self):
        return "猫猫叫"

cat = Cat('小咪', '3', 'nan', '白色') 
print(cat)
# cat.color
cat.say()
# Out:
# name:小咪, age:3, sex:nan, color:白色
# '猫猫叫'

# %%
class Dog(Animal):
    def say(self):
        return '汪汪叫'

# %%
def sayHello(animal):
    return animal.say()

# %%
cat = Cat('小咪', '3', 'nan', '白色') 
dog = Dog('大黄', '3', 'nv')
print(sayHello(cat))
print(sayHello(dog))
# Out:
# 猫猫叫
# 汪汪叫

# %% [markdown]
# 同样的行为(函数)，传入不同的对象，得到不同的状态
