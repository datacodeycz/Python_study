# %% [markdown]
# 1.创建一个集合 fruits，包含 "apple", "banana", "orange"，并打印这个集合。

# %% [markdown]
# 2.在集合 numbers = {1, 2, 3} 中添加元素 4，并输出结果。

# %% [markdown]
# 3.删除集合 nums = {1, 2, 3, 4} 中的元素 3，并打印删除后的集合。

# %% [markdown]
# 4.编写程序判断 "apple" 是否在 fruits = {"apple", "banana", "orange"} 中。

# %% [markdown]
# 5.创建集合 data = {1, 2, 3}，使用 clear() 方法清空集合并打印。

# %% [markdown]
# 6.给定集合 A = {1, 2, 3}，B = {3, 4, 5}，求并集并打印结果。

# %% [markdown]
# 7.给定集合 A = {"a", "b", "c"}，B = {"b", "c", "d"}，求交集并输出。

# %% [markdown]
# 8.给定集合 A = {1, 2, 3}，B = {2, 3, 4}，求 A - B，并输出结果。

# %% [markdown]
# 9.给定集合 A = {1, 2, 3}，B = {3, 4, 5}，输出两个集合的对称差集。

# %% [markdown]
# 10.给定集合 A = {1, 2}，B = {1, 2, 3}，判断 A 是否是 B 的子集。

# %% [markdown]
# 11.给定列表 nums = [1, 2, 2, 3, 4, 4, 5]，使用集合去重，并输出去重后的列表。

# %% [markdown]
# 12.输入一个字符串，输出其中不重复字符的数量。

# %% [markdown]
# 13.找出两个班级的共同学生
#
# 班级 A 的学生：{"Tom", "Alice", "Bob"}
#
# 班级 B 的学生：{"Bob", "David", "Alice"}
#
# 找出两个班都有的学生。

# %% [markdown]
# 14.给定两个列表 l1 = [1, 2, 3]，l2 = [3, 4, 5]，判断它们是否有交集。

# %% [markdown]
# 15.用字典实现一个简单的联系人信息系统，支持存储姓名和电话号，并可打印出来。

# %% [markdown]
# 16.合并以下两个字典
#
# ```python
#
# stu_1 = {
#
#     'id':'20240101',
#
#     'name':'xiaoming',
#
#     'sex':'nan',
#
#     'course' : 'python network mysql',
#
# }
#
# dict_2 = {
#
#     'a':1,
#
#     'b':2,
#
#     'c':3
#
# }
#
# ```

# %% [markdown]
# 17.编写程序，遍历以下字典并打印每一个键与值
#
#
#
# ```python
#
# stu_1 = {
#
#     'id':'20240101',
#
#     'name':'xiaoming',
#
#     'sex':'nan',
#
#     'course' : 'python network mysql',
#
# }
#
# ```

# %% [markdown]
# 18.给定如下字典`student = {"name": "Tom", "score": 88}`，修改其中 "score" 的值为 95

# %% [markdown]
# 19.创建一个空字典，然后添加以下键值对：
#    - "name": "Alice"
#    - "gender": "female"
#    - "score": 90

# %% [markdown]
# 20.使用嵌套字典表示多个学生的选课信息。
#
# 每个学生包含：
#
# `name`（姓名）
# `courses`（课程信息，是一个嵌套字典）
#
#     `python程序设计`
#     `mysql库数据`
#     `network`
#
#     每门课程包含：
#         credit（学分）
#         teacher（任课老师）
#         required（是否必修）
#
# 要求：
#
# 1.添加 2 位学生，每人选修至少 2 门课程
#
# 2.打印每个学生的所有课程信息
#
# 3.统计并输出每位学生的总学分
