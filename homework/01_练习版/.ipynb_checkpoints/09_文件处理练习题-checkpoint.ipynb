# %% [markdown]
# 1.请编写一个程序，将字符串列表 `["apple", "banana", "cherry"]` 写入文件 `fruits.txt`，放在data文件夹下面，每个字符串占一行。
# 写入完成后，读取该文件并打印内容。

# %% [markdown]
# 2.编写程序读取名为`article.txt`的文件(文件在data下面)，统计其中的行数，并输出行数结果。
