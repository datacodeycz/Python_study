# %% [markdown]
# 1.编写一个Python程序，要求用户输入一个整数，如果这个数是正数，输出"这是一个正数"，否则输出"这不是一个正数"。
#
#     1.要求用户输入  int(input())
#     2.判断这个数是否为一个正数 num > 0 正数  否则 不是一个正数

# %%
num = int(input("请输入一个整数："))
if num > 0:
    print('这是一个正数')
else:
    print('这不是一个正数')
# Out:
# 请输入一个整数： -1
# 这不是一个正数

# %% [markdown]
# 2.使用分支语句实现，当你的年龄为18岁及以上时，你可以报名驾校，如果你的年龄在18岁以下，你不能报名驾校

# %% [markdown]
# 3.输入三个数字，判断这三个数字是否能够组成三角形

# %%
l1 = float(input('请输入三角形的第一条边'))
l2 = float(input('请输入三角形的第二条边'))
l3 = float(input('请输入三角形的第三条边'))

if l1 + l2 > l3 and l1 + l3 > l2 and l2 + l3 > l1:
    print("可以构成三角形")
else:
    print('不可以构成三角形')

# %% [markdown]
# 4.通过你输入的成绩，判断你成绩的等级，90-100 为A，80-89 为B，70-79 为 C，60-69为D，60分以下为 E

# %% [markdown]
# 5.当你的年龄为18岁及以上，或75岁以下时，你可以报名驾校，如果你的年龄在18岁以下，或75岁以上，你不能报名驾校（使用多分支语句）

# %% [markdown]
# 6.当你的年龄为18-75岁时，你可以报考驾校，但是得通过体检(是否为红绿色盲)，是红绿色盲，体检不通过，不是红绿色盲，体检通过

# %% [markdown]
# 7.求1-100的和，并输出

# %% [markdown]
# 8.输出"水仙花数".水仙花数是指1个3位的十进制，其各位数字的立方和恰好等于该数本身。例如，153是水仙花数，
#
# 因为$153 = 1^3 + 5^3+ 3^3$

# %% [markdown]
# 9.在1-20找到偶数，并输出

# %% [markdown]
# 10.实现九九乘法表

# %%
for y in range(1, 9 + 1):
    for x in range(1, y+1):
        print(f'{x} * {y} = {x * y}', end='   ')
    print('\t')
# Out:
# 1 * 1 = 1
# 1 * 2 = 2   2 * 2 = 4
# 1 * 3 = 3   2 * 3 = 6   3 * 3 = 9
# 1 * 4 = 4   2 * 4 = 8   3 * 4 = 12   4 * 4 = 16
# 1 * 5 = 5   2 * 5 = 10   3 * 5 = 15   4 * 5 = 20   5 * 5 = 25
# 1 * 6 = 6   2 * 6 = 12   3 * 6 = 18   4 * 6 = 24   5 * 6 = 30   6 * 6 = 36
# 1 * 7 = 7   2 * 7 = 14   3 * 7 = 21   4 * 7 = 28   5 * 7 = 35   6 * 7 = 42   7 * 7 = 49
# 1 * 8 = 8   2 * 8 = 16   3 * 8 = 24   4 * 8 = 32   5 * 8 = 40   6 * 8 = 48   7 * 8 = 56   8 * 8 = 64
# 1 * 9 = 9   2 * 9 = 18   3 * 9 = 27   4 * 9 = 36   5 * 9 = 45   6 * 9 = 54   7 * 9 = 63   8 * 9 = 72   9 * 9 = 81
