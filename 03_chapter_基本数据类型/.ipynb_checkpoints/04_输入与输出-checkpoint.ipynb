# %% [markdown]
# # 输入与输出
#
# 这里主要是讲解print函数和input函数的使用

# %% [markdown]
# ## 字符串的基础使用
#
# 创建字符串的方式
# 1. `''`
# 2. `""`
# 3. `''' '''`
# 4. `""" """`

# %%
str_1 = 'python'

# %%
str_2 = "python"
print(str_2)
# Out:
# python

# %% [markdown]
# `\\  == \`\
# `\' == '` \
# `\" == "`\
# `\n == 换行`\
# `\t == 制表符`

# %%
str_3 = "pyt\nhon"
print(str_3)
# Out:
# pyt
# hon

# %% [markdown]
# 问题1.在使用双引号的字符串中我想要保留字符串中的双引号怎么办<br>
# 答：借助`\`转义字符来表示

# %%
str_3 = "py\"thon"  # \" == "
print(str_3)
# Out:
# py"thon

# %%
str_3 = "py\thon"  # \" == "
print(str_3)
# Out:
# py	hon

# %%
str_4 = 'python\npython_1'
print(str_4)
# Out:
# python
# python_1

# %%
url = 'https://vodpub6.v.news.cn/yqfbzx-original/20230818\
/20230818bd5de7446029436cb41e0ff2c37e1c54_\
606f38a617a746988c4bb396538066dd.mp4'
print(url)
# Out:
# https://vodpub6.v.news.cn/yqfbzx-original/20230818/20230818bd5de7446029436cb41e0ff2c37e1c54_606f38a617a746988c4bb396538066dd.mp4

# %%
# 字符串的拼接
str_1 = 'hello'
str_2 = 'world'
str_1 + str_2
# Out:
# 'helloworld'

# %% [markdown]
# ## print语句
#
# print函数用于输出在控制台的内容
#
# print语句的格式\
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)\
# objects -- 复数，表示可以一次输出多个对象。输出多个对象时，需要用 , 分隔。\
# sep -- 用来间隔多个对象，默认值是一个空格。\
# end -- 用来设定以什么结尾。默认值是换行符 \n，我们可以换成其他字符串。\
# file -- 要写入的文件对象。\
# flush -- 输出是否被缓存通常决定于 file，但如果 flush 关键字参数为 True，流会被强制刷新。

# %%
print(1, 2, 3, 4, 5, 6, sep='%', end='我是最后结束的内容')
print(2)
# Out:
# 1%2%3%4%5%6我是最后结束的内容2

# %% [markdown]
# `sep`和`end`参数一定要用关键字传入参数

# %% [markdown]
# ## input
# input()函数：\
# 功能：获取我们的输入内容\
# 输入（参数）：展示在控制台中的内容\
# 输出（返回值）：我们输入的内容 注意：返回值默认是字符串类型的\
# 注意：由于input()的返回值（控制台获取的内容）是字符串，但是有时候我们想用其他数据类型的，就需要借助我们上面上述的数据类型之间的转换
# int() float()等等

# %%
score = float(input("请输入你的python成绩"))

print(score)
print(type(score))
# Out:
# 请输入你的python成绩 100
# 100.0
# <class 'float'>

# %% [markdown]
# 请输入你的python，mysql network的成绩，并计算这个成绩的平均值，将这个python成绩和mysql成绩和network成绩和平均打印同时打印出来到控制台

# %%
score_python = float(input("请输入你的python成绩："))
score_mysql = float(input("请输入你的mysql成绩："))
score_network = float(input("请输入你的network成绩："))
avg = (score_python + score_mysql + score_network) / 3
print(avg)

str_python = "你的python成绩为" + str(score_python)
str_mysql = "你的mysql成绩为" + str(score_mysql)
str_network = "你的network成绩为" + str(score_network)

print(str_python, str_mysql, str_network, sep='\n')
# Out:
# 请输入你的python成绩： 100
# 请输入你的mysql成绩： 100
# 请输入你的network成绩： 100
# 100.0
# 你的python成绩为100.0
# 你的mysql成绩为100.0
# 你的network成绩为100.0
